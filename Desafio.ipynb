# %%
import pandas as pd

# %%
emisiones_gases = pd.read_excel("1-SEEG10_GERAL-BR_UF_2022.10.27-FINAL-SITE.xlsx", sheet_name="GEE Estados")
# Out:
# c:\Users\luish\anaconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
emision_gases = emisiones_gases[emisiones_gases["Emissão / Remoção / Bunker"] == "Emissão"]

# %%
columnas_info = list(emisiones_gases.loc[:, "Nível 1 - Setor": "Produto"].columns)

# %%
columnas_emision = list(emisiones_gases.loc[:, 1970:2021].columns)

# %%
emision_por_año = emisiones_gases.melt(id_vars = columnas_info, value_vars = columnas_emision, var_name= "Año", value_name="Emision")
emision_por_año
# Out:
#                             Nível 1 - Setor  \
# 0                     Processos Industriais
# 1                     Processos Industriais
# 2                     Processos Industriais
# 3                     Processos Industriais
# 4                     Processos Industriais
# ...                                     ...
# 5372219  Mudança de Uso da Terra e Floresta
# 5372220  Mudança de Uso da Terra e Floresta
# 5372221  Mudança de Uso da Terra e Floresta
# 5372222  Mudança de Uso da Terra e Floresta
# 5372223  Mudança de Uso da Terra e Floresta
#
#                                          Nível 2                    Nível 3  \
# 0                              Indústria Química            Produção de ABS
# 1                              Indústria Química  Produção de Ácido Adípico
# 2                              Indústria Química  Produção de Ácido Adípico
# 3                              Indústria Química  Produção de Ácido Adípico
# ...

# %% [markdown]
# ### **Desafio-CAPITULO 1**

# %% [markdown]
# 1. Encuentre los valores únicos de las columnas "Nível 1 - Setor" y "Estado" para identificar las actividades económicas presentes en la base de datos y si todos los estados brasileños están presentes en el DataFrame.

# %%
valores_unicos_setor = emisiones_gases["Nível 1 - Setor"].unique()
Valores_unicos_estado = emisiones_gases["Estado"].unique()

# %% [markdown]
# 2. Filtrar el DataFrame sólo con datos de estados de la región sur de Brasil.

# %%
Valores_unicos_estado
# Out:
# array(['SP', 'BA', 'RJ', 'MG', 'SE', 'PR', nan, 'RO', 'AM', 'PA', 'TO',
#        'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'MT', 'MS', 'GO', 'DF',
#        'ES', 'SC', 'RS', 'AC', 'AP', 'RR', 'BR'], dtype=object)

# %%
emisiones_gases[emisiones_gases['Estado'].isin(['PR', 'RS', 'SC'])]
# Out:
#                             Nível 1 - Setor              Nível 2  \
# 35                    Processos Industriais    Indústria Química
# 36                    Processos Industriais    Indústria Química
# 37                    Processos Industriais    Indústria Química
# 110                   Processos Industriais    Produtos Minerais
# 111                   Processos Industriais    Produtos Minerais
# ...                                     ...                  ...
# 5372133  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 5372134  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 5372135  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 5372136  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 5372137  Mudança de Uso da Terra e Floresta  Resíduos Florestais
#
#                      Nível 3 Nível 4       Nível 5 Nível 6  \
# 35        Produção de Amônia     NaN           NaN     NaN
# 36        Produção de Amônia     NaN           NaN     NaN
# ...

# %% [markdown]
# 3. Filtrar el DataFrame sólo con datos de "Mudança de Uso da Terra e Floresta" que sean del Estado de Amazonas.

# %%
valores_unicos_setor
# Out:
# array(['Processos Industriais', 'Agropecuária', 'Energia', 'Resíduos ',
#        'Mudança de Uso da Terra e Floresta'], dtype=object)

# %%
emisiones_gases[(emisiones_gases["Nível 1 - Setor"] == 'Mudança de Uso da Terra e Floresta') | (emisiones_gases["Estado"] == "EA")]
# Out:
#                             Nível 1 - Setor  \
# 81260    Mudança de Uso da Terra e Floresta
# 81261    Mudança de Uso da Terra e Floresta
# 81262    Mudança de Uso da Terra e Floresta
# 81263    Mudança de Uso da Terra e Floresta
# 81264    Mudança de Uso da Terra e Floresta
# ...                                     ...
# 5372219  Mudança de Uso da Terra e Floresta
# 5372220  Mudança de Uso da Terra e Floresta
# 5372221  Mudança de Uso da Terra e Floresta
# 5372222  Mudança de Uso da Terra e Floresta
# 5372223  Mudança de Uso da Terra e Floresta
#
#                                          Nível 2   Nível 3  \
# 81260                 Alterações de Uso da Terra  Amazônia
# 81261                 Alterações de Uso da Terra  Amazônia
# 81262                 Alterações de Uso da Terra  Amazônia
# 81263                 Alterações de Uso da Terra  Amazônia
# 81264                 Alterações de Uso da Terra  Amazônia
# ...                                          ...       ...
# ...

# %% [markdown]
# 4. Encuentre el valor máximo de emisión para el año 2021 para los datos de "Agropecuária" en el Estado de Pará.

# %%
emisiones_gases.loc[(emision_gases["Nível 1 - Setor"] == 'Agropecuária') & (emisiones_gases["Estado"] == "PA"), 2021].max()
# Out:
# 36856969.7986

# %% [markdown]
# ### **Desafio-CAPITULO 2**

# %% [markdown]
# 1. Agrupe los datos según la columna "Nível 1 - Setor" para ver el diccionario que contiene las llaves de los grupos formados y la lista de índices para cada grupo.

# %%
emision_por_año.groupby("Nível 1 - Setor").groups
# Out:
# {'Agropecuária': [1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, ...], 'Energia': [24735, 24736, 24737, 24738, 24739, 24740, 24741, 24742, 24743, 24744, 24745, 24746, 24747, 24748, 24749, 24750, 24751, 24752, 24753, 24754, 24755, 24756, 24757, 24758, 24759, 24760, 24761, 24762, 24763, 24764, 24765, 24766, 24767, 24768, 24769, 24770, 24771, 24772, 24773, 24774, 24775, 24776, 24777, 24778, 24779, 24780, 24781, 24782, 24783, 24784, 24785, 24786
# ...

# %% [markdown]
# 2. Agrupe los datos según la columna "Nível 1 - Setor" y ubique los datos del grupo "Agropecuária".

# %%
emision_por_año.groupby("Nível 1 - Setor").get_group("Agropecuária")
# Out:
#         Nível 1 - Setor           Nível 2  Nível 3  \
# 1137       Agropecuária  Cultivo de Arroz  Diretas
# 1138       Agropecuária  Cultivo de Arroz  Diretas
# 1139       Agropecuária  Cultivo de Arroz  Diretas
# 1140       Agropecuária  Cultivo de Arroz  Diretas
# 1141       Agropecuária  Cultivo de Arroz  Diretas
# ...                 ...               ...      ...
# 5293642    Agropecuária   Solos Manejados  Diretas
# 5293643    Agropecuária   Solos Manejados  Diretas
# 5293644    Agropecuária   Solos Manejados  Diretas
# 5293645    Agropecuária   Solos Manejados  Diretas
# 5293646    Agropecuária   Solos Manejados  Diretas
#
#                                           Nível 4  Nível 5  \
# 1137                                       Outros  Vegetal
# 1138                                       Outros  Vegetal
# 1139                                       Outros  Vegetal
# 1140                                       Outros  Vegetal
# ...

# %% [markdown]
# 3. Agrupe los datos con base en la columna “Nível 1 - Setor” para identificar la emisión promedio de cada actividad económica en 2021.

# %%
emision_por_año[emision_por_año["Año"] == 2021].groupby("Nível 1 - Setor")[["Emision"]].mean()
# Out:
#                                           Emision
# Nível 1 - Setor
# Agropecuária                         53082.725943
# Energia                              75120.049185
# Mudança de Uso da Terra e Floresta  196843.405133
# Processos Industriais               787101.255789
# Resíduos                            106106.723386

# %% [markdown]
# 4. Agrupe los datos con base en la columna "Nível 1 - Setor" para identificar la suma de emisiones de cada actividad económica. Ordene los datos de mayor a menor emisión.

# %%
emision_por_año.groupby("Nível 1 - Setor")[["Emision"]].sum().sort_values("Emision", ascending=False)
# Out:
#                                          Emision
# Nível 1 - Setor
# Mudança de Uso da Terra e Floresta  2.494463e+11
# Energia                             1.244170e+11
# Agropecuária                        1.107286e+11
# Processos Industriais               2.849965e+10
# Resíduos                            1.034465e+10
