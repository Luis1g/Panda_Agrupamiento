# %% [markdown]
# 1. Encuentre los valores únicos de las columnas "Nível 1 - Setor" y "Estado" para identificar las actividades económicas presentes en la base de datos y si todos los estados brasileños están presentes en el DataFrame.

# %%
import pandas as pd

# %%
emisiones_gases = pd.read_excel("1-SEEG10_GERAL-BR_UF_2022.10.27-FINAL-SITE.xlsx", sheet_name="GEE Estados")
# Out:
# c:\Users\luish\anaconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
valores_unicos_setor = emisiones_gases["Nível 1 - Setor"].unique()
Valores_unicos_estado = emisiones_gases["Estado"].unique()

# %% [markdown]
# 2. Filtrar el DataFrame sólo con datos de estados de la región sur de Brasil.

# %%
Valores_unicos_estado
# Out:
# array(['SP', 'BA', 'RJ', 'MG', 'SE', 'PR', nan, 'RO', 'AM', 'PA', 'TO',
#        'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'MT', 'MS', 'GO', 'DF',
#        'ES', 'SC', 'RS', 'AC', 'AP', 'RR', 'BR'], dtype=object)

# %%
emisiones_gases[emisiones_gases['Estado'].isin(['PR', 'RS', 'SC'])]
# Out:
#                            Nível 1 - Setor              Nível 2  \
# 35                   Processos Industriais    Indústria Química
# 36                   Processos Industriais    Indústria Química
# 37                   Processos Industriais    Indústria Química
# 110                  Processos Industriais    Produtos Minerais
# 111                  Processos Industriais    Produtos Minerais
# ...                                    ...                  ...
# 103221  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103222  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103223  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103224  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103225  Mudança de Uso da Terra e Floresta  Resíduos Florestais
#
#                     Nível 3 Nível 4       Nível 5 Nível 6  \
# 35       Produção de Amônia     NaN           NaN     NaN
# 36       Produção de Amônia     NaN           NaN     NaN
# 37       Produção de Amônia     NaN           NaN     NaN
# 110     Produção de Cimento     NaN           NaN     NaN
# 111     Produção de Cimento     NaN           NaN     NaN
# ...                     ...     ...           ...     ...
# 103221                Pampa     NaN  Desmatamento     NaN
# 103222                Pampa     NaN  Desmatamento     NaN
# 103223                Pampa     NaN  Desmatamento     NaN
# 103224                Pampa     NaN  Desmatamento     NaN
# 103225                Pampa     NaN  Desmatamento     NaN
#
#        Emissão / Remoção / Bunker               Gás Estado  \
# 35                        Emissão           CO2 (t)     PR
# 36                        Emissão  CO2e (t) GWP-AR2     PR
# 37                        Emissão  CO2e (t) GTP-AR2     PR
# 110                       Emissão           CO2 (t)     PR
# 111                       Emissão           CO2 (t)     SC
# ...                           ...               ...    ...
# 103221                    Emissão  CO2e (t) GWP-AR2     RS
# 103222                    Emissão  CO2e (t) GWP-AR4     RS
# 103223                    Emissão  CO2e (t) GWP-AR5     RS
# 103224                    Emissão  CO2e (t) GWP-AR6     RS
# 103225                    Emissão           N2O (t)     RS
#
#        Atividade Econômica  ...          2012          2013          2014  \
# 35               OUTRA_IND  ...  4.562042e+05  4.682616e+05  5.151689e+05
# 36               OUTRA_IND  ...  4.562042e+05  4.682616e+05  5.151689e+05
# 37               OUTRA_IND  ...  4.562042e+05  4.682616e+05  5.151689e+05
# 110                    CIM  ...  2.012596e+06  2.212002e+06  2.241143e+06
# 111                    CIM  ...  7.126368e+05  6.421719e+05  8.163383e+05
# ...                    ...  ...           ...           ...           ...
# 103221             AGROPEC  ...  1.108518e+06  1.479183e+06  9.718840e+05
# 103222             AGROPEC  ...  1.196999e+06  1.599471e+06  1.045298e+06
# 103223             AGROPEC  ...  1.221927e+06  1.635136e+06  1.062603e+06
# 103224             AGROPEC  ...  1.232994e+06  1.649637e+06  1.072887e+06
# 103225             AGROPEC  ...  1.726602e+03  2.272649e+03  1.572510e+03
#
#                 2015          2016          2017          2018          2019  \
# 35      5.151689e+05  5.151689e+05  5.151689e+05  5.151689e+05  5.151689e+05
# 36      5.151689e+05  5.151689e+05  5.151689e+05  5.151689e+05  5.151689e+05
# 37      5.151689e+05  5.151689e+05  5.151689e+05  5.151689e+05  5.151689e+05
# 110     2.176752e+06  2.279061e+06  2.115372e+06  2.173266e+06  2.230656e+06
# 111     6.769844e+05  5.272686e+05  5.143665e+05  5.130451e+05  5.451073e+05
# ...              ...           ...           ...           ...           ...
# 103221  9.948190e+05  7.698680e+05  9.057280e+05  9.238730e+05  1.046432e+06
# 103222  1.070678e+06  8.308050e+05  9.748940e+05  9.924510e+05  1.124747e+06
# 103223  1.089187e+06  8.475340e+05  9.918540e+05  1.007627e+06  1.142614e+06
# 103224  1.099601e+06  8.553060e+05  1.001321e+06  1.017557e+06  1.153771e+06
# 103225  1.599308e+03  1.206486e+03  1.454739e+03  1.511353e+03  1.704000e+03
#
#                 2020          2021
# 35      5.151689e+05  5.151689e+05
# 36      5.151689e+05  5.151689e+05
# 37      5.151689e+05  5.151689e+05
# 110     2.488650e+06  2.845457e+06
# 111     6.144431e+05  7.179804e+05
# ...              ...           ...
# 103221  1.439095e+06  1.432812e+06
# 103222  1.543126e+06  1.541087e+06
# 103223  1.563684e+06  1.566694e+06
# 103224  1.579514e+06  1.581831e+06
# 103225  2.399000e+03  2.313000e+03
#
# [12212 rows x 63 columns]

# %% [markdown]
# 3. Filtrar el DataFrame sólo con datos de "Mudança de Uso da Terra e Floresta" que sean del Estado de Amazonas.

# %%
valores_unicos_setor
# Out:
# array(['Processos Industriais', 'Agropecuária', 'Energia', 'Resíduos ',
#        'Mudança de Uso da Terra e Floresta'], dtype=object)

# %%
emisiones_gases[(emisiones_gases["Nível 1 - Setor"] == 'Mudança de Uso da Terra e Floresta') | (emisiones_gases["Estado"] == "EA")]
# Out:
#                            Nível 1 - Setor  \
# 81260   Mudança de Uso da Terra e Floresta
# 81261   Mudança de Uso da Terra e Floresta
# 81262   Mudança de Uso da Terra e Floresta
# 81263   Mudança de Uso da Terra e Floresta
# 81264   Mudança de Uso da Terra e Floresta
# ...                                    ...
# 103307  Mudança de Uso da Terra e Floresta
# 103308  Mudança de Uso da Terra e Floresta
# 103309  Mudança de Uso da Terra e Floresta
# 103310  Mudança de Uso da Terra e Floresta
# 103311  Mudança de Uso da Terra e Floresta
#
#                                         Nível 2   Nível 3  \
# 81260                Alterações de Uso da Terra  Amazônia
# 81261                Alterações de Uso da Terra  Amazônia
# 81262                Alterações de Uso da Terra  Amazônia
# 81263                Alterações de Uso da Terra  Amazônia
# 81264                Alterações de Uso da Terra  Amazônia
# ...                                         ...       ...
# 103307  Queimadas Não Associadas a Desmatamento  Pantanal
# 103308  Queimadas Não Associadas a Desmatamento  Pantanal
# 103309  Queimadas Não Associadas a Desmatamento  Pantanal
# 103310  Queimadas Não Associadas a Desmatamento  Pantanal
# 103311  Queimadas Não Associadas a Desmatamento  Pantanal
#
#                        Nível 4       Nível 5  \
# 81260   fora de Área Protegida  Desmatamento
# 81261   fora de Área Protegida  Desmatamento
# 81262   fora de Área Protegida  Desmatamento
# 81263   fora de Área Protegida  Desmatamento
# 81264   fora de Área Protegida  Desmatamento
# ...                        ...           ...
# 103307                     NaN           NaN
# 103308                     NaN           NaN
# 103309                     NaN           NaN
# 103310                     NaN           NaN
# 103311                     NaN           NaN
#
#                                         Nível 6 Emissão / Remoção / Bunker  \
# 81260   Floresta primária -- Área sem vegetação                    Emissão
# 81261   Floresta primária -- Área sem vegetação                    Emissão
# 81262   Floresta primária -- Área sem vegetação                    Emissão
# 81263   Floresta primária -- Área sem vegetação                    Emissão
# 81264   Floresta primária -- Área sem vegetação                    Emissão
# ...                                         ...                        ...
# 103307                                      NaN                Emissão NCI
# 103308                                      NaN                Emissão NCI
# 103309                                      NaN                Emissão NCI
# 103310                                      NaN                Emissão NCI
# 103311                                      NaN                Emissão NCI
#
#                      Gás Estado Atividade Econômica  ...       2012  \
# 81260            CO2 (t)     AC             AGROPEC  ...    16999.0
# 81261            CO2 (t)     AP             AGROPEC  ...   107986.0
# 81262            CO2 (t)     AM             AGROPEC  ...    85118.0
# 81263            CO2 (t)     MA             AGROPEC  ...    88293.0
# 81264            CO2 (t)     MT             AGROPEC  ...   308599.0
# ...                  ...    ...                 ...  ...        ...
# 103307  CO2e (t) GTP-AR6     BR                 NaN  ...  2731963.4
# 103308  CO2e (t) GWP-AR2     BR                 NaN  ...  2921341.0
# 103309  CO2e (t) GWP-AR4     BR                 NaN  ...  2950049.0
# 103310  CO2e (t) GWP-AR5     BR                 NaN  ...  2957780.0
# 103311  CO2e (t) GWP-AR6     BR                 NaN  ...  2953478.0
#
#              2013      2014       2015       2016       2017      2018  \
# 81260     13480.0   17894.0    13156.0    13480.0    12781.0   39241.0
# 81261    124606.0  102106.0    68134.0   159307.0    10159.0   62298.0
# 81262     97637.0   87619.0   121815.0   113759.0    52998.0   61170.0
# 81263     75524.0   41744.0    58566.0    59864.0    47675.0   46018.0
# 81264    345374.0  267595.0   313342.0   359681.0   427458.0  439442.0
# ...           ...       ...        ...        ...        ...       ...
# 103307  1091033.9  853275.3  1003731.4  1615000.6  1552258.8  216231.9
# 103308  1144504.0  896685.0  1074717.0  1763431.0  1706030.0  252599.0
# 103309  1151848.0  902209.0  1084073.0  1782863.0  1726958.0  257507.0
# 103310  1152868.0  902368.0  1084826.0  1784237.0  1729598.0  258068.0
# 103311  1151967.0  901817.0  1083792.0  1782129.0  1727086.0  257491.0
#
#              2019        2020     2021
# 81260      9121.0      8106.0  19221.0
# 81261     13611.0      3918.0   3562.0
# 81262     48264.0     14381.0  31867.0
# 81263     90130.0     45443.0  39316.0
# 81264    528622.0    336659.0  85118.0
# ...           ...         ...      ...
# 103307  2805297.3   9659261.2      0.0
# 103308  3105007.0  10535710.0      0.0
# 103309  3147567.0  10675682.0      0.0
# 103310  3155415.0  10722317.0      0.0
# 103311  3149790.0  10699479.0      0.0
#
# [22052 rows x 63 columns]

# %% [markdown]
# 4. Encuentre el valor máximo de emisión para el año 2021 para los datos de "Agropecuária" en el Estado de Pará.

# %%
emisiones_gases.loc[(emisiones_gases["Nível 1 - Setor"] == 'Agropecuária') & (emisiones_gases["Estado"] == "PA"), 2021].max()
# Out:
# 36856969.7986
